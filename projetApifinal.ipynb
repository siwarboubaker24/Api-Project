# %%
import pyodbc 
import sys
import requests
import json
import pandas

# %%
r1=requests.get("http://universities.hipolabs.com/search?name=University")

# %%
print(r1)
# Out:
# <Response [200]>

# %%
dat=r1.json()

# %%
dat
# Out:
# [{'alpha_two_code': 'US',
#   'web_pages': ['http://www.ipfw.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'Indiana University/Purdue University at Fort Wayne',
#   'domains': ['ipfw.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.iupui.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'Indiana University/Purdue University at Indianapolis',
#   'domains': ['iupui.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.iupuc.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'Indiana University/Purdue University at Columbus',
#   'domains': ['iupuc.edu']},
#  {'alpha_two_code': 'PL',
#   'web_pages': ['http://www.wsb-nlu.edu.pl/'],
#   'country': 'Poland',
#   'state-province': None,
#   'name': 'Higher School o Business/National Louis University(WSB/NLU) in Nowy Sacz',
#   'domains': ['wsb-nlu.edu.pl']},
#  {'alpha_two_code': 'SK',
#   'web_pages': ['http://www.ukf.sk/'],
#   'country': 'Slovakia',
#   'state-province': None,
#   'name': 'University Konstantina Filozov in Nitra',
#   'domains': ['ukf.sk']},
#  {'alpha_two_code': 'AL',
#   'web_pages': ['http://www.unipavaresia.edu.al/'],
#   'country': 'Albania',
#   'state-province': None,
#   'name': 'University “Pavaresia” Vlore',
#   'domains': ['unipavaresia.edu.al']},
#  {'alpha_two_code': 'CH',
#   'web_pages': ['http://www.uccr.edu/'],
#   'country': 'Switzerland',
#   'state-province': None,
#   'name': 'University Center "César Ritz"',
#   'domains': ['uccr.edu']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.hsvest.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'University Centre of the Westfjords',
#   'domains': ['hsvest.is']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ucs.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University Campus Suffolk',
#   'domains': ['ucs.ac.uk']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.universitycanadawest.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University Canada West',
#   'domains': ['universitycanadawest.ca']},
#  {'alpha_two_code': 'IE',
#   'web_pages': ['http://www.ucc.ie/'],
#   'country': 'Ireland',
#   'state-province': None,
#   'name': 'University College Cork',
#   'domains': ['ucc.ie']},
#  {'alpha_two_code': 'IE',
#   'web_pages': ['http://www.ucd.ie/'],
#   'country': 'Ireland',
#   'state-province': None,
#   'name': 'University College Dublin',
#   'domains': ['ucd.ie']},
#  {'alpha_two_code': 'BH',
#   'web_pages': ['http://www.ucb.edu.bh/'],
#   'country': 'Bahrain',
#   'state-province': None,
#   'name': 'University College Bahrain',
#   'domains': ['ucb.edu.bh']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ucl.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University College London, University of London',
#   'domains': ['ucl.ac.uk']},
#  {'alpha_two_code': 'SE',
#   'web_pages': ['http://www.hkr.se/'],
#   'country': 'Sweden',
#   'state-province': None,
#   'name': 'University College of Kristianstad',
#   'domains': ['hkr.se']},
#  {'alpha_two_code': 'SE',
#   'web_pages': ['http://www.hb.se/'],
#   'country': 'Sweden',
#   'state-province': None,
#   'name': 'University College of Borås',
#   'domains': ['hb.se']},
#  {'alpha_two_code': 'SE',
#   'web_pages': ['http://www.hig.se/'],
#   'country': 'Sweden',
#   'state-province': None,
#   'name': 'University College of Gävle',
#   'domains': ['hig.se']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.uccb.ns.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University College of Cape Breton',
#   'domains': ['uccb.ns.ca']},
#  {'alpha_two_code': 'SE',
#   'web_pages': ['http://www.his.se/'],
#   'country': 'Sweden',
#   'state-province': None,
#   'name': 'University College of Skövde',
#   'domains': ['his.se']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.ustboniface.mb.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University College of Saint-Boniface',
#   'domains': ['ustboniface.mb.ca']},
#  {'alpha_two_code': 'PS',
#   'web_pages': ['http://www.ucas.edu.ps/'],
#   'country': 'Palestine, State of',
#   'state-province': None,
#   'name': 'University College of Applied Sciences',
#   'domains': ['ucas.edu.ps']},
#  {'alpha_two_code': 'SE',
#   'web_pages': ['http://www.konstfack.se/'],
#   'country': 'Sweden',
#   'state-province': None,
#   'name': 'University College of Arts, Crafts and Design',
#   'domains': ['konstfack.se']},
#  {'alpha_two_code': 'IR',
#   'web_pages': ['http://www.ucna.info/'],
#   'country': 'Iran',
#   'state-province': 'East Azerbaijan',
#   'name': 'University College of Nabi Akram',
#   'domains': ['ucna.info']},
#  {'alpha_two_code': 'MY',
#   'web_pages': ['http://www.ucti.edu.my/'],
#   'country': 'Malaysia',
#   'state-province': None,
#   'name': 'University College of Technology & Innovation (UCTI)',
#   'domains': ['ucti.edu.my']},
#  {'alpha_two_code': 'SE',
#   'web_pages': ['http://www.htu.se/'],
#   'country': 'Sweden',
#   'state-province': None,
#   'name': 'University College of Trollhättan/Uddevalla',
#   'domains': ['htu.se']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.cariboo.bc.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University College of the Cariboo',
#   'domains': ['cariboo.bc.ca']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.ucfv.bc.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University College of the Fraser Valley',
#   'domains': ['ucfv.bc.ca']},
#  {'alpha_two_code': 'PL',
#   'web_pages': ['http://www.awf.krakow.pl/'],
#   'country': 'Poland',
#   'state-province': None,
#   'name': 'University School of Physical Education',
#   'domains': ['awf.krakow.pl']},
#  {'alpha_two_code': 'MK',
#   'web_pages': ['http://www.ugd.edu.mk/'],
#   'country': 'Macedonia, the Former Yugoslav Republic of',
#   'state-province': None,
#   'name': 'University Goce Delcev',
#   'domains': ['ugd.edu.mk']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.iulm.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University Institute of Modern Languages',
#   'domains': ['iulm.it']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unisob.na.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University Institute of Teacher Training "Suor Orsola Benincasa"',
#   'domains': ['unisob.na.it']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.iuav.unive.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University Institute of Architecture Venice',
#   'domains': ['iuav.unive.it']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.uninav.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University Institute of Naval Studies',
#   'domains': ['uninav.it']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.iuo.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University Institute of Oriental Studies',
#   'domains': ['iuo.it']},
#  {'alpha_two_code': 'HR',
#   'web_pages': ['http://www.unin.hr/'],
#   'country': 'Croatia',
#   'state-province': None,
#   'name': 'University North',
#   'domains': ['unin.hr']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.dote.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'University Medical School of Debrecen',
#   'domains': ['dote.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.pote.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'University Medical School of Pécs',
#   'domains': ['pote.hu']},
#  {'alpha_two_code': 'CG',
#   'web_pages': ['http://www.univ-mngb.net/'],
#   'country': 'Congo',
#   'state-province': None,
#   'name': 'University Marien Ngouabi Brazzaville',
#   'domains': ['univ-mngb.net']},
#  {'alpha_two_code': 'MY',
#   'web_pages': ['http://www.ump.edu.my/'],
#   'country': 'Malaysia',
#   'state-province': None,
#   'name': 'University Malaysia Pahang',
#   'domains': ['ump.edu.my']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.uav.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University "Aurel Vlaicu" Arad',
#   'domains': ['uav.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.upa.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University "Petre Andrei" Iasi',
#   'domains': ['upa.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.unitbv.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University "Transilvany" of Brasov',
#   'domains': ['unitbv.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.utm.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University "Titu Maiorescu"',
#   'domains': ['utm.ro']},
#  {'alpha_two_code': 'BA',
#   'web_pages': ['http://www.unvi.edu.ba/'],
#   'country': 'Bosnia and Herzegovina',
#   'state-province': None,
#   'name': 'University Vitez In Travnik',
#   'domains': ['unvi.edu.ba']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.ulbsibiu.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University Lucian Blaga of Sibiu',
#   'domains': ['ulbsibiu.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.upg-ploiesti.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University Oil- Gas Ploiesti',
#   'domains': ['upg-ploiesti.ro']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uakron.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Akron',
#   'domains': ['uakron.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.wayne.uakron.edu'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Akron Wayne College',
#   'domains': ['wayne.uakron.edu']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.unak.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'University of Akureyri',
#   'domains': ['unak.is']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.abdn.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Aberdeen',
#   'domains': ['abdn.ac.uk', 'aberdeen.ac.uk']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.abertay.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Abertay Dundee',
#   'domains': ['abertay.ac.uk']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.unibuja.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Abuja',
#   'domains': ['unibuja.edu.ng']},
#  {'alpha_two_code': 'BG',
#   'web_pages': ['http://www.uacg.bg/'],
#   'country': 'Bulgaria',
#   'state-province': None,
#   'name': 'University of Architecture, Civil Engineering and Geodesy',
#   'domains': ['uacg.bg']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uaccm.edu'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas Community College-\u200bMorrilton',
#   'domains': ['uaccm.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uaccb.edu'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas Community College-\u200bBatesville',
#   'domains': ['uaccb.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uacch.edu'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas Community College-\u200bHope',
#   'domains': ['uacch.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uamont.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas - Monticello',
#   'domains': ['uamont.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uark.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas - Fayetteville',
#   'domains': ['uark.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uafs.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas - Fort Smith',
#   'domains': ['uafs.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.ualr.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas - Little Rock',
#   'domains': ['ualr.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['https://www.uasys.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas System eVersity',
#   'domains': ['uasys.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uams.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arkansas for Medical Sciences',
#   'domains': ['uams.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.arizona.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Arizona',
#   'domains': ['arizona.edu']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.uartdcluj.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Art and Design Cluj-Napoca',
#   'domains': ['uartdcluj.ro']},
#  {'alpha_two_code': 'FI',
#   'web_pages': ['http://www.uiah.fi/'],
#   'country': 'Finland',
#   'state-province': None,
#   'name': 'University of Art and Design Helsinki',
#   'domains': ['uiah.fi']},
#  {'alpha_two_code': 'YE',
#   'web_pages': ['http://www.adenuniversity.edu.ye/'],
#   'country': 'Yemen',
#   'state-province': None,
#   'name': 'University of Aden',
#   'domains': ['adenuniversity.edu.ye']},
#  {'alpha_two_code': 'AU',
#   'web_pages': ['http://www.adelaide.edu.au/'],
#   'country': 'Australia',
#   'state-province': None,
#   'name': 'University of Adelaide',
#   'domains': ['adelaide.edu.au']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uat.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Advancing Technology',
#   'domains': ['uat.edu']},
#  {'alpha_two_code': 'PH',
#   'web_pages': ['http://www.uap.edu.ph/'],
#   'country': 'Philippines',
#   'state-province': None,
#   'name': 'University of Asia and the Pacific',
#   'domains': ['uap.edu.ph']},
#  {'alpha_two_code': 'BD',
#   'web_pages': ['http://www.uap-bd.edu/'],
#   'country': 'Bangladesh',
#   'state-province': None,
#   'name': 'University of Asia Pacific, Dhanmondi',
#   'domains': ['uap-bd.edu']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.univaq.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Aquila',
#   'domains': ['univaq.it']},
#  {'alpha_two_code': 'JP',
#   'web_pages': ['http://www.u-aizu.ac.jp/'],
#   'country': 'Japan',
#   'state-province': None,
#   'name': 'University of Aizu',
#   'domains': ['u-aizu.ac.jp']},
#  {'alpha_two_code': 'EE',
#   'web_pages': ['http://www.tktk.ee/'],
#   'country': 'Estonia',
#   'state-province': None,
#   'name': 'University of Applied Sciences',
#   'domains': ['tktk.ee']},
#  {'alpha_two_code': 'CH',
#   'web_pages': ['http://www.fh-htachur.ch/'],
#   'country': 'Switzerland',
#   'state-province': None,
#   'name': 'University of Applied Sciences Chur',
#   'domains': ['fh-htachur.ch']},
#  {'alpha_two_code': 'CH',
#   'web_pages': ['http://www.fhso.ch/'],
#   'country': 'Switzerland',
#   'state-province': None,
#   'name': 'University of Applied Sciences Solothurn Northwestern Switzerland',
#   'domains': ['fhso.ch']},
#  {'alpha_two_code': 'CH',
#   'web_pages': ['http://www.fhbb.ch/'],
#   'country': 'Switzerland',
#   'state-province': None,
#   'name': 'University of Applied Sciences Basel (FHBB )',
#   'domains': ['fhbb.ch']},
#  {'alpha_two_code': 'CH',
#   'web_pages': ['http://www.fh-aargau.ch/'],
#   'country': 'Switzerland',
#   'state-province': None,
#   'name': 'University of Applied Sciences Aargau',
#   'domains': ['fh-aargau.ch']},
#  {'alpha_two_code': 'MD',
#   'web_pages': ['http://www.usam.md/'],
#   'country': 'Moldova, Republic of',
#   'state-province': None,
#   'name': 'University of Applied Sciences of Moldova',
#   'domains': ['usam.md']},
#  {'alpha_two_code': 'IR',
#   'web_pages': ['http://www.uast.ac.ir/'],
#   'country': 'Iran',
#   'state-province': 'Tehran',
#   'name': 'University of Applied Science and Technology',
#   'domains': ['uast.ac.ir']},
#  {'alpha_two_code': 'NL',
#   'web_pages': ['http://www.uva.nl/'],
#   'country': 'Netherlands',
#   'state-province': None,
#   'name': 'University of Amsterdam',
#   'domains': ['uva.nl']},
#  {'alpha_two_code': 'TN',
#   'web_pages': ['http://www.unat.ens.tn/'],
#   'country': 'Tunisia',
#   'state-province': None,
#   'name': 'University of Aviation and Technology',
#   'domains': ['unat.ens.tn']},
#  {'alpha_two_code': 'NZ',
#   'web_pages': ['http://www.auckland.ac.nz/'],
#   'country': 'New Zealand',
#   'state-province': None,
#   'name': 'University of Auckland',
#   'domains': ['auckland.ac.nz']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.uam.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Agriculture Makurdi',
#   'domains': ['uam.edu.ng']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.unaab.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Agriculture Abeokuta',
#   'domains': ['unaab.edu.ng']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.usamvcluj.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Agriculture and Veterinary Medicine Cluj-Napoca',
#   'domains': ['usamvcluj.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.usab.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Agriculture and Veterinary Medicine Bucharest',
#   'domains': ['usab.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.univagro-iasi.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Agriculture and Veterinary Medicine Iasi',
#   'domains': ['univagro-iasi.ro']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.usab-tm.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Agriculture and Veterinary Medicine Timisoara',
#   'domains': ['usab-tm.ro']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.uaf.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': None,
#   'name': 'University of Agriculture Faisalabad',
#   'domains': ['uaf.edu.pk']},
#  {'alpha_two_code': 'IN',
#   'web_pages': ['http://www.uasd.net/'],
#   'country': 'India',
#   'state-province': None,
#   'name': 'University of Agricultural Sciences, Dharwad',
#   'domains': ['uasd.net']},
#  {'alpha_two_code': 'IN',
#   'web_pages': ['http://uasbng.kar.nic.in/'],
#   'country': 'India',
#   'state-province': None,
#   'name': 'University of Agricultural Sciences, Bangalore',
#   'domains': ['uasbng.kar.nic.in']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unian.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Ancona',
#   'domains': ['unian.it']},
#  {'alpha_two_code': 'AD',
#   'web_pages': ['http://www.uda.ad/'],
#   'country': 'Andorra',
#   'state-province': None,
#   'name': 'University of Andorra',
#   'domains': ['uda.ad']},
#  {'alpha_two_code': 'IQ',
#   'web_pages': ['http://www.uoanbar.edu.iq/'],
#   'country': 'Iraq',
#   'state-province': None,
#   'name': 'University of Anbar',
#   'domains': ['uoanbar.edu.iq']},
#  {'alpha_two_code': 'SK',
#   'web_pages': ['http://www.tnuni.sk/'],
#   'country': 'Slovakia',
#   'state-province': None,
#   'name': 'University of Alexandra Dubček in Trenčín',
#   'domains': ['tnuni.sk']},
#  {'alpha_two_code': 'SY',
#   'web_pages': ['http://www.alepuniv.edu.sy/'],
#   'country': 'Syrian Arab Republic',
#   'state-province': None,
#   'name': 'University of Aleppo',
#   'domains': ['alepuniv.edu.sy']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.ualberta.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of Alberta',
#   'domains': ['ualberta.ca']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.alaska.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alaska',
#   'domains': ['alaska.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uas.alaska.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alaska - Southeast',
#   'domains': ['uas.alaska.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uaa.alaska.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alaska - Anchorage',
#   'domains': ['uaa.alaska.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uaf.edu'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alaska - Fairbanks',
#   'domains': ['uaf.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uah.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alabama at Huntsville',
#   'domains': ['uah.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uab.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alabama at Birmingham',
#   'domains': ['uab.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.ua.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Alabama at Tuscaloosa',
#   'domains': ['ua.edu']},
#  {'alpha_two_code': 'IQ',
#   'web_pages': ['http://www.qadissuni.edu.iq/'],
#   'country': 'Iraq',
#   'state-province': None,
#   'name': 'University of Al-Qadisiyah',
#   'domains': ['qadissuni.edu.iq']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.uoa.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'University of Athens',
#   'domains': ['uoa.gr']},
#  {'alpha_two_code': 'SD',
#   'web_pages': ['http://www.uofg.edu.sd/'],
#   'country': 'Sudan',
#   'state-province': None,
#   'name': 'University of Gezira',
#   'domains': ['uofg.edu.sd']},
#  {'alpha_two_code': 'CH',
#   'web_pages': ['http://www.unige.ch/'],
#   'country': 'Switzerland',
#   'state-province': None,
#   'name': 'University of Geneva',
#   'domains': ['unige.ch']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unige.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Genoa',
#   'domains': ['unige.it']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uga.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Georgia',
#   'domains': ['uga.edu']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.gre.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Greenwich',
#   'domains': ['gre.ac.uk']},
#  {'alpha_two_code': 'GL',
#   'web_pages': ['http://www.ilisimatusarfik.gl/'],
#   'country': 'Greenland',
#   'state-province': None,
#   'name': 'University of Greenland',
#   'domains': ['ilisimatusarfik.gl']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.ugf.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Great Falls',
#   'domains': ['ugf.edu']},
#  {'alpha_two_code': 'GE',
#   'web_pages': ['http://www.gruni.edu.ge/'],
#   'country': 'Georgia',
#   'state-province': None,
#   'name': 'University of Grigol Robakidze',
#   'domains': ['gruni.edu.ge']},
#  {'alpha_two_code': 'NL',
#   'web_pages': ['http://www.rug.nl/'],
#   'country': 'Netherlands',
#   'state-province': None,
#   'name': 'University of Groningen',
#   'domains': ['rug.nl']},
#  {'alpha_two_code': 'GY',
#   'web_pages': ['http://www.uog.edu.gy/'],
#   'country': 'Guyana',
#   'state-province': None,
#   'name': 'University of Guyana',
#   'domains': ['uog.edu.gy']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.uog.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': 'Panjab',
#   'name': 'University of Gujrat',
#   'domains': ['uog.edu.pk']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.uoguelph.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of Guelph',
#   'domains': ['uoguelph.ca']},
#  {'alpha_two_code': 'GU',
#   'web_pages': ['http://www.uog.edu/'],
#   'country': 'Guam',
#   'state-province': None,
#   'name': 'University of Guam',
#   'domains': ['uog.edu']},
#  {'alpha_two_code': 'IR',
#   'web_pages': ['http://www.guilan.ac.ir/'],
#   'country': 'Iran',
#   'state-province': 'Gilan',
#   'name': 'University of Guilan',
#   'domains': ['guilan.ac.ir']},
#  {'alpha_two_code': 'PG',
#   'web_pages': ['http://www.uog.ac.pg/'],
#   'country': 'Papua New Guinea',
#   'state-province': None,
#   'name': 'University of Goroka',
#   'domains': ['uog.ac.pg']},
#  {'alpha_two_code': 'PL',
#   'web_pages': ['http://www.univ.gda.pl/'],
#   'country': 'Poland',
#   'state-province': None,
#   'name': 'University of Gdansk',
#   'domains': ['univ.gda.pl']},
#  {'alpha_two_code': 'AL',
#   'web_pages': ['http://www.uogj.edu.al/'],
#   'country': 'Albania',
#   'state-province': None,
#   'name': 'University of Gjirokstra "Eqerem Cabej"',
#   'domains': ['uogj.edu.al']},
#  {'alpha_two_code': 'SD',
#   'web_pages': ['http://www.gaduniv.edu.sd/'],
#   'country': 'Sudan',
#   'state-province': None,
#   'name': 'University of Gadarif',
#   'domains': ['gaduniv.edu.sd']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unisg.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Gastronomic Sciences',
#   'domains': ['unisg.it']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.ugal.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Galatzi',
#   'domains': ['ugal.ro']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.glam.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Glamorgan',
#   'domains': ['glam.ac.uk']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.gla.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Glasgow',
#   'domains': ['gla.ac.uk']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.glos.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Gloucestershire',
#   'domains': ['glos.ac.uk']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.ug.edu.gh/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'University of Ghana',
#   'domains': ['ug.edu.gh']},
#  {'alpha_two_code': 'QA',
#   'web_pages': ['http://www.qu.edu.qa/'],
#   'country': 'Qatar',
#   'state-province': None,
#   'name': 'University of Qatar',
#   'domains': ['qu.edu.qa']},
#  {'alpha_two_code': 'AU',
#   'web_pages': ['http://www.uq.edu.au/'],
#   'country': 'Australia',
#   'state-province': None,
#   'name': 'University of Queensland',
#   'domains': ['uq.edu.au']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.uquebec.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of Québec',
#   'domains': ['uquebec.ca']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.ui.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Ibadan',
#   'domains': ['ui.edu.ng']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uiowa.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Iowa',
#   'domains': ['uiowa.edu']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.uoi.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'University of Ioannina',
#   'domains': ['uoi.gr']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.hi.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'University of Iceland',
#   'domains': ['hi.is']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uidaho.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Idaho',
#   'domains': ['uidaho.edu']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.uaic.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Iasi',
#   'domains': ['uaic.ro']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uindy.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Indianapolis',
#   'domains': ['uindy.edu']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.uindy.edu.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'University of Indianapolis in Athens',
#   'domains': ['uindy.edu.gr']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.uninsubria.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Insubria',
#   'domains': ['uninsubria.it']},
#  {'alpha_two_code': 'PL',
#   'web_pages': ['http://www.wsub.waw.pl/'],
#   'country': 'Poland',
#   'state-province': None,
#   'name': 'University of Insurance and Banking in Warsaw',
#   'domains': ['wsub.waw.pl']},
#  {'alpha_two_code': 'PL',
#   'web_pages': ['http://www.wsiz.rzeszow.pl/'],
#   'country': 'Poland',
#   'state-province': None,
#   'name': 'University of Information Technology and Management in Rzeszow',
#   'domains': ['wsiz.rzeszow.pl']},
#  {'alpha_two_code': 'BD',
#   'web_pages': ['http://www.uits.edu.bd/'],
#   'country': 'Bangladesh',
#   'state-province': None,
#   'name': 'University of Information Technology & Sciences',
#   'domains': ['uits.edu.bd']},
#  {'alpha_two_code': 'KZ',
#   'web_pages': ['http://www.uib.kz/'],
#   'country': 'Kazakhstan',
#   'state-province': None,
#   'name': 'University of International Business',
#   'domains': ['uib.kz']},
#  {'alpha_two_code': 'CN',
#   'web_pages': ['http://www.uibe.edu.cn/'],
#   'country': 'China',
#   'state-province': None,
#   'name': 'University of International Business and Economics',
#   'domains': ['uibe.edu.cn']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uic.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Illinois at Chicago',
#   'domains': ['uic.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uis.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Illinois at Springfield',
#   'domains': ['uis.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.illinois.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Illinois at Urbana-Champaign',
#   'domains': ['uiuc.edu', 'illinois.edu']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.unilorin.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Ilorin',
#   'domains': ['unilorin.edu.ng']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unistrasi.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Italian Studies for Foreigners of Siena',
#   'domains': ['unistrasi.it']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unistrapg.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Italian Studies for Foreigners of Perugia',
#   'domains': ['unistrapg.it']},
#  {'alpha_two_code': 'FI',
#   'web_pages': ['http://www.jyu.fi/'],
#   'country': 'Finland',
#   'state-province': None,
#   'name': 'University of Jyväskylä',
#   'domains': ['jyu.fi']},
#  {'alpha_two_code': 'IN',
#   'web_pages': ['http://www.jammuvarsity.org/'],
#   'country': 'India',
#   'state-province': None,
#   'name': 'University of Jammu',
#   'domains': ['jammuvarsity.org']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uj.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Jamestown',
#   'domains': ['uj.edu']},
#  {'alpha_two_code': 'CZ',
#   'web_pages': ['http://www.ujep.cz/'],
#   'country': 'Czech Republic',
#   'state-province': None,
#   'name': 'University of Jan Evangelista Purkyne',
#   'domains': ['ujep.cz']},
#  {'alpha_two_code': 'LK',
#   'web_pages': ['http://www.jfn.ac.lk/'],
#   'country': 'Sri Lanka',
#   'state-province': None,
#   'name': 'University of Jaffna',
#   'domains': ['jfn.ac.lk']},
#  {'alpha_two_code': 'AE',
#   'web_pages': ['http://www.uojazeera.com/'],
#   'country': 'United Arab Emirates',
#   'state-province': None,
#   'name': 'University of Jazeera',
#   'domains': ['uojazeera.com']},
#  {'alpha_two_code': 'SS',
#   'web_pages': ['http://www.juba.edu.sd/'],
#   'country': 'South Sudan',
#   'state-province': None,
#   'name': 'University of Juba',
#   'domains': ['juba.edu.sd']},
#  {'alpha_two_code': 'CN',
#   'web_pages': ['http://www.ujn.edu.cn/'],
#   'country': 'China',
#   'state-province': None,
#   'name': 'University of Jinan',
#   'domains': ['ujn.edu.cn']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.unijos.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Jos',
#   'domains': ['unijos.edu.ng']},
#  {'alpha_two_code': 'FI',
#   'web_pages': ['http://www.joensuu.fi/'],
#   'country': 'Finland',
#   'state-province': None,
#   'name': 'University of Joensuu',
#   'domains': ['joensuu.fi']},
#  {'alpha_two_code': 'JO',
#   'web_pages': ['http://www.ju.edu.jo/'],
#   'country': 'Jordan',
#   'state-province': None,
#   'name': 'University of Jordan',
#   'domains': ['ju.edu.jo']},
#  {'alpha_two_code': 'ZA',
#   'web_pages': ['http://www.uj.ac.za/'],
#   'country': 'South Africa',
#   'state-province': None,
#   'name': 'University of Johannesburg',
#   'domains': ['uj.ac.za']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ex.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Exeter',
#   'domains': ['ex.ac.uk']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.evansville.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Evansville',
#   'domains': ['evansville.edu']},
#  {'alpha_two_code': 'BG',
#   'web_pages': ['http://www.ue-varna.bg/'],
#   'country': 'Bulgaria',
#   'state-province': None,
#   'name': 'University of Economics Varna',
#   'domains': ['ue-varna.bg']},
#  {'alpha_two_code': 'CZ',
#   'web_pages': ['http://www.vse.cz/'],
#   'country': 'Czech Republic',
#   'state-province': None,
#   'name': 'University of Economics Prague',
#   'domains': ['vse.cz']},
#  {'alpha_two_code': 'SK',
#   'web_pages': ['http://www.euba.sk/'],
#   'country': 'Slovakia',
#   'state-province': None,
#   'name': 'University of Economics in Bratislava',
#   'domains': ['euba.sk']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ed.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Edinburgh',
#   'domains': ['ed.ac.uk']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.ue.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': None,
#   'name': 'University of Education',
#   'domains': ['ue.edu.pk']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.uew.edu.gh/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'University of Education, Winneba',
#   'domains': ['uew.edu.gh']},
#  {'alpha_two_code': 'CZ',
#   'web_pages': ['http://www.vsp.cz/'],
#   'country': 'Czech Republic',
#   'state-province': None,
#   'name': 'University of Education Hradec Kralove',
#   'domains': ['vsp.cz']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.essex.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Essex',
#   'domains': ['essex.ac.uk']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.uoe.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': None,
#   'name': 'University of East',
#   'domains': ['uoe.edu.pk']},
#  {'alpha_two_code': 'KE',
#   'web_pages': ['http://www.ueab.ac.ke/'],
#   'country': 'Kenya',
#   'state-province': None,
#   'name': 'University of Eastern Africa, Baraton',
#   'domains': ['ueab.ac.ke']},
#  {'alpha_two_code': 'PH',
#   'web_pages': ['http://www.uep.educ.ph/'],
#   'country': 'Philippines',
#   'state-province': None,
#   'name': 'University of Eastern Philippines',
#   'domains': ['uep.educ.ph']},
#  {'alpha_two_code': 'BA',
#   'web_pages': ['http://www.unssa.rs.ba/'],
#   'country': 'Bosnia and Herzegovina',
#   'state-province': None,
#   'name': 'University of East Srarajevo',
#   'domains': ['unssa.rs.ba']},
#  {'alpha_two_code': 'JP',
#   'web_pages': ['http://www.toua-u.ac.jp/'],
#   'country': 'Japan',
#   'state-province': None,
#   'name': 'University of East Asia',
#   'domains': ['toua-u.ac.jp']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.uea.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of East Anglia',
#   'domains': ['uea.ac.uk']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.uel.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of East London',
#   'domains': ['uel.ac.uk']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.nwfpuet.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': 'Khyber Pakhtunkhwa',
#   'name': 'University of Engineering and Technology Peshawar',
#   'domains': ['nwfpuet.edu.pk']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.uet.edu/'],
#   'country': 'Pakistan',
#   'state-province': None,
#   'name': 'University of Engineering and Technology Lahore',
#   'domains': ['uet.edu']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.uettaxila.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': None,
#   'name': 'University of Engineering and Technology Taxila',
#   'domains': ['uettaxila.edu.pk']},
#  {'alpha_two_code': 'KE',
#   'web_pages': ['http://www.uoeld.ac.ke/'],
#   'country': 'Kenya',
#   'state-province': None,
#   'name': 'University of Eldoret',
#   'domains': ['uoeld.ac.ke']},
#  {'alpha_two_code': 'JP',
#   'web_pages': ['http://www.uec.ac.jp/'],
#   'country': 'Japan',
#   'state-province': None,
#   'name': 'University of Electro-Communications',
#   'domains': ['uec.ac.jp']},
#  {'alpha_two_code': 'CN',
#   'web_pages': ['http://www.uestc.edu.cn/'],
#   'country': 'China',
#   'state-province': None,
#   'name': 'University of Electronic Science and Technology of China',
#   'domains': ['uestc.edu.cn']},
#  {'alpha_two_code': 'AL',
#   'web_pages': ['http://www.uniel.edu.al/'],
#   'country': 'Albania',
#   'state-province': None,
#   'name': 'University of Elbasan "Aleksander Xhuvani"',
#   'domains': ['uniel.edu.al']},
#  {'alpha_two_code': 'SD',
#   'web_pages': ['http://www.elmahdi.edu.sd/'],
#   'country': 'Sudan',
#   'state-province': None,
#   'name': 'University of El Imam El Mahdi University',
#   'domains': ['elmahdi.edu.sd']},
#  {'alpha_two_code': 'SK',
#   'web_pages': ['http://www.uvm.sk/'],
#   'country': 'Slovakia',
#   'state-province': None,
#   'name': 'University of Veterinary Medicine in Kosice',
#   'domains': ['uvm.sk']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.univet.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'University of Veterinary Science',
#   'domains': ['univet.hu']},
#  {'alpha_two_code': 'CZ',
#   'web_pages': ['http://www.vfu.cz/'],
#   'country': 'Czech Republic',
#   'state-province': None,
#   'name': 'University of Veterinary and Pharmaceutical Science',
#   'domains': ['vfu.cz']},
#  {'alpha_two_code': 'PK',
#   'web_pages': ['http://www.uvas.edu.pk/'],
#   'country': 'Pakistan',
#   'state-province': 'Panjab',
#   'name': 'University of Veterinary & Animal Science',
#   'domains': ['uvas.edu.pk']},
#  {'alpha_two_code': 'ZA',
#   'web_pages': ['http://www.univen.ac.za/'],
#   'country': 'South Africa',
#   'state-province': None,
#   'name': 'University of Venda',
#   'domains': ['univen.ac.za']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unive.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Venice',
#   'domains': ['unive.it']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uvm.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Vermont',
#   'domains': ['uvm.edu']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.univr.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Verona',
#   'domains': ['univr.it']},
#  {'alpha_two_code': 'FI',
#   'web_pages': ['http://www.uwasa.fi/'],
#   'country': 'Finland',
#   'state-province': None,
#   'name': 'University of Vaasa',
#   'domains': ['uwasa.fi']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.uvic.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of Victoria',
#   'domains': ['uvic.ca']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.virginia.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Virginia, Charlottesville',
#   'domains': ['virginia.edu']},
#  {'alpha_two_code': 'AL',
#   'web_pages': ['http://www.univlora.edu.al/'],
#   'country': 'Albania',
#   'state-province': None,
#   'name': 'University of Vlora "Ismail Qemali"',
#   'domains': ['univlora.edu.al']},
#  {'alpha_two_code': 'NG',
#   'web_pages': ['http://www.uniuyo.edu.ng/'],
#   'country': 'Nigeria',
#   'state-province': None,
#   'name': 'University of Uyo',
#   'domains': ['uniuyo.edu.ng']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.uniud.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Udine',
#   'domains': ['uniud.it']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.uniurb.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Urbino',
#   'domains': ['uniurb.it']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ulst.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Ulster',
#   'domains': ['ulst.ac.uk']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.utah.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Utah',
#   'domains': ['utah.edu']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ox.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Oxford',
#   'domains': ['ox.ac.uk']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.ou.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Oklahoma',
#   'domains': ['ou.edu']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.uoit.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of Ontario Institute of Technology',
#   'domains': ['uoit.ca']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uoregon.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Oregon',
#   'domains': ['uoregon.edu']},
#  {'alpha_two_code': 'RO',
#   'web_pages': ['http://www.uoradea.ro/'],
#   'country': 'Romania',
#   'state-province': None,
#   'name': 'University of Oradea',
#   'domains': ['uoradea.ro']},
#  {'alpha_two_code': 'FI',
#   'web_pages': ['http://www.oulu.fi/'],
#   'country': 'Finland',
#   'state-province': None,
#   'name': 'University of Oulu',
#   'domains': ['oulu.fi']},
#  {'alpha_two_code': 'JP',
#   'web_pages': ['http://www.uoeh-u.ac.jp/'],
#   'country': 'Japan',
#   'state-province': None,
#   'name': 'University of Occupational and Environmental Health, Japan',
#   'domains': ['uoeh-u.ac.jp']},
#  {'alpha_two_code': 'NO',
#   'web_pages': ['http://www.uio.no/'],
#   'country': 'Norway',
#   'state-province': None,
#   'name': 'University of Oslo',
#   'domains': ['uio.no']},
#  {'alpha_two_code': 'HR',
#   'web_pages': ['http://www.unios.hr/'],
#   'country': 'Croatia',
#   'state-province': None,
#   'name': 'University of Osijek',
#   'domains': ['unios.hr']},
#  {'alpha_two_code': 'CZ',
#   'web_pages': ['http://www.osu.cz/'],
#   'country': 'Czech Republic',
#   'state-province': None,
#   'name': 'University of Ostrava',
#   'domains': ['osu.cz']},
#  {'alpha_two_code': 'PL',
#   'web_pages': ['http://www.uni.opole.pl/'],
#   'country': 'Poland',
#   'state-province': None,
#   'name': 'University of Opole',
#   'domains': ['uni.opole.pl']},
#  {'alpha_two_code': 'NZ',
#   'web_pages': ['http://www.otago.ac.nz/'],
#   'country': 'New Zealand',
#   'state-province': None,
#   'name': 'University of Otago',
#   'domains': ['otago.ac.nz']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.uottawa.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of Ottawa',
#   'domains': ['uottawa.ca']},
#  {'alpha_two_code': 'AU',
#   'web_pages': ['http://www.newcastle.edu.au/'],
#   'country': 'Australia',
#   'state-province': None,
#   'name': 'University of Newcastle',
#   'domains': ['newcastle.edu.au']},
#  {'alpha_two_code': 'GB',
#   'web_pages': ['http://www.ncl.ac.uk/'],
#   'country': 'United Kingdom',
#   'state-province': None,
#   'name': 'University of Newcastle-upon-Tyne',
#   'domains': ['ncl.ac.uk']},
#  {'alpha_two_code': 'NC',
#   'web_pages': ['http://www.ufp.nc/'],
#   'country': 'New Caledonia',
#   'state-province': None,
#   'name': 'University of New Caledonia',
#   'domains': ['ufp.nc']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.unb.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of New Brunswick',
#   'domains': ['unb.ca']},
#  {'alpha_two_code': 'CA',
#   'web_pages': ['http://www.unbsj.ca/'],
#   'country': 'Canada',
#   'state-province': None,
#   'name': 'University of New Brunswick, Saint John',
#   'domains': ['unbsj.ca']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unm.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of New Mexico',
#   'domains': ['unm.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.uno.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of New Orleans',
#   'domains': ['uno.edu']},
#  {'alpha_two_code': 'CZ',
#   'web_pages': ['http://www.unyp.cz/'],
#   'country': 'Czech Republic',
#   'state-province': None,
#   'name': 'University of New York in Prague',
#   'domains': ['unyp.cz']},
#  {'alpha_two_code': 'AL',
#   'web_pages': ['http://www.unyt.edu.al/'],
#   'country': 'Albania',
#   'state-province': None,
#   'name': 'University of New York Tirana',
#   'domains': ['unyt.edu.al']},
#  {'alpha_two_code': 'AU',
#   'web_pages': ['http://www.unsw.edu.au/'],
#   'country': 'Australia',
#   'state-province': None,
#   'name': 'University of New South Wales',
#   'domains': ['unsw.edu.au']},
#  {'alpha_two_code': 'AU',
#   'web_pages': ['http://www.une.edu.au/'],
#   'country': 'Australia',
#   'state-province': None,
#   'name': 'University of New England',
#   'domains': ['une.edu.au']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unh.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of New Hampshire, Durham',
#   'domains': ['unh.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.newhaven.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of New Haven',
#   'domains': ['newhaven.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unk.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Nebraska, Kearney',
#   'domains': ['unk.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unl.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Nebraska, Lincoln',
#   'domains': ['unl.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unomaha.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Nebraska, Omaha',
#   'domains': ['unomaha.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unr.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Nevada, Reno',
#   'domains': ['unr.edu']},
#  {'alpha_two_code': 'US',
#   'web_pages': ['http://www.unlv.edu/'],
#   'country': 'United States',
#   'state-province': None,
#   'name': 'University of Nevada, Las Vegas',
#   'domains': ['unlv.edu']},
#  {'alpha_two_code': 'PH',
#   'web_pages': ['http://www.uno-r.edu.ph/'],
#   'country': 'Philippines',
#   'state-province': None,
#   'name': 'University of Negros Occidental-Recoletos',
#   'domains': ['uno-r.edu.ph']},
#  {'alpha_two_code': 'NA',
#   'web_pages': ['http://www.unam.na/'],
#   'country': 'Namibia',
#   'state-province': None,
#   'name': 'University of Namibia',
#   'domains': ['unam.na']},
#  {'alpha_two_code': 'IT',
#   'web_pages': ['http://www.unina.it/'],
#   'country': 'Italy',
#   'state-province': None,
#   'name': 'University of Naples Federico II',
#   'domains': ['unina.it']},
#  {'alpha_two_code': 'KE',
#   'web_pages': ['http://www.uonbi.ac.ke/'],
#   'country': 'Kenya',
#   'state-province': None,
#   'name': 'University of Nairobi',
#   'domains': ['uonbi.ac.ke']},
#  {'alpha_two_code': 'BG',
#   'web_pages': ['http://www.unwe.acad.bg/'],
#   'country': 'Bulgaria',
#   'state-province': None,
#   'name': 'University of National and World Economy',
#   'domains': ['unwe.acad.bg']},
#  {'alpha_two_code': 'PH',
#   'web_pages': ['http://www.unc.edu.ph/'],
#   'country': 'Philippines',
#   'state-province': None,
#   'name': 'University of Nueva Caceres',
#   'domains': ['unc.edu.ph']},
#  {'alpha_two_code': 'CY',
#   'web_pages': ['http://www.unic.ac.cy/'],
#   'country': 'Cyprus',
#   'state-province': None,
#   'name': 'University of Nicosia',
# ...
#  {'alpha_two_code': 'BD',
#   'web_pages': ['http://www.wub.edu/'],
#   'country': 'Bangladesh',
#   'state-province': None,
#   'name': 'World University of Bangladesh',
#   'domains': ['wub.edu']},
#  {'alpha_two_code': 'BE',
#   'web_pages': ['http://www.uhasselt.be/'],
#   'country': 'Belgium',
#   'state-province': None,
#   'name': 'Hasselt University',
#   'domains': ['uhasselt.be']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.brsu.brest.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Brest State University',
#   'domains': ['brsu.brest.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bseu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State Economic University',
#   'domains': ['bseu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bru.mogilev.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarusian-Russian University',
#   'domains': ['bru.mogilev.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bsmu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State Medical University',
#   'domains': ['bsmu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bntu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian National Technical University',
#   'domains': ['bntu.by']},
#  {'alpha_two_code': 'BE',
#   'web_pages': ['http://www.europeaniu.org/'],
#   'country': 'Belgium',
#   'state-province': None,
#   'name': 'European International University',
#   'domains': ['europeaniu.org']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.data.minsk.by/ehu/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'European Humanities University',
#   'domains': ['data.minsk.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bsuir.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State University of Informatics and Radioelectronics',
#   'domains': ['bsuir.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.buk.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State University of Culture and Arts',
#   'domains': ['buk.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bstu.unibel.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State Technological University',
#   'domains': ['bstu.unibel.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bstu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Brest State Technical University',
#   'domains': ['bstu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bsu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State University',
#   'domains': ['bsu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.bspu.unibel.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State Pedagogical University M. Tanka',
#   'domains': ['bspu.unibel.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.vsu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Vitebsk State University',
#   'domains': ['vsu.by']},
#  {'alpha_two_code': 'BE',
#   'web_pages': ['http://www.brexgata.eu/'],
#   'country': 'Belgium',
#   'state-province': None,
#   'name': 'Brexgata University Academy',
#   'domains': ['brexgata.eu']},
#  {'alpha_two_code': 'BE',
#   'web_pages': ['http://www.carolus-magnus-university.eu/'],
#   'country': 'Belgium',
#   'state-province': None,
#   'name': 'European Carolus Magnus University',
#   'domains': ['carolus-magnus-university.eu']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://msu.mogilev.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Mogilev State University A.A. Kuleshov',
#   'domains': ['msu.mogilev.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.mslu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Minsk State Linguistic University',
#   'domains': ['mslu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.psu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Polotsk State University',
#   'domains': ['psu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.uni-agro.grodno.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Grodno State Agrarian University',
#   'domains': ['uni-agro.grodno.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.vstu.vitebsk.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Vitebsk State Technological University',
#   'domains': ['vstu.vitebsk.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.vgmu.vitebsk.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Vitebsk State Medical University',
#   'domains': ['vgmu.vitebsk.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.grsmu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Grodno State Medical University',
#   'domains': ['grsmu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.gsu.unibel.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Gomel State University Francisk Scarnia',
#   'domains': ['gsu.unibel.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.gstu.gomel.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Gomel State Technical University Pavel Sukhoi',
#   'domains': ['gstu.gomel.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.grsu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Grodno State University Yanka Kupaly',
#   'domains': ['grsu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.belsut.gomel.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State University of Transport',
#   'domains': ['belsut.gomel.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.batu.edu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Belarussian State Agrarian Technical University',
#   'domains': ['batu.edu.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.meduniver.gomel.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'Gomel State Medical University',
#   'domains': ['meduniver.gomel.by']},
#  {'alpha_two_code': 'BY',
#   'web_pages': ['http://www.iseu.by/'],
#   'country': 'Belarus',
#   'state-province': None,
#   'name': 'International Sakharov Environmental University',
#   'domains': ['iseu.by']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.uion.edu.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Ionian University Corfu',
#   'domains': ['uion.edu.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.tuc.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Technical University of Crete',
#   'domains': ['tuc.gr']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.ln.edu.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'Lingnan University',
#   'domains': ['ln.edu.hk']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.hkbu.edu.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'Hong Kong Baptist University',
#   'domains': ['hkbu.edu.hk']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.ouhk.edu.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'Open University of Hong Kong',
#   'domains': ['ouhk.edu.hk']},
#  {'alpha_two_code': 'HT',
#   'web_pages': ['http://www.auchaiti.org/'],
#   'country': 'Haiti',
#   'state-province': None,
#   'name': 'American University of the Caribbean',
#   'domains': ['auchaiti.org']},
#  {'alpha_two_code': 'GY',
#   'web_pages': ['http://www.tauedu.org/'],
#   'country': 'Guyana',
#   'state-province': None,
#   'name': 'Texila American University',
#   'domains': ['tauedu.org']},
#  {'alpha_two_code': 'GY',
#   'web_pages': ['http://www.gemsvilleuniversity.com/'],
#   'country': 'Guyana',
#   'state-province': None,
#   'name': 'Gemsville Technical University',
#   'domains': ['gemsvilleuniversity.com']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.cityu.edu.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'City University of Hong Kong',
#   'domains': ['cityu.edu.hk']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.cuhk.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'Chinese University of Hong Kong',
#   'domains': ['cuhk.hk']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.polyu.edu.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'Hong Kong Polytechnic University',
#   'domains': ['polyu.edu.hk']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.agr.unideb.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Debrecen University of Agricultural Sciences',
#   'domains': ['agr.unideb.hu']},
#  {'alpha_two_code': 'HK',
#   'web_pages': ['http://www.ust.hk/'],
#   'country': 'Hong Kong',
#   'state-province': None,
#   'name': 'Hong Kong University of Science and Technology',
#   'domains': ['ust.hk']},
#  {'alpha_two_code': 'GD',
#   'web_pages': ['http://www.sgu.edu/'],
#   'country': 'Grenada',
#   'state-province': None,
#   'name': "St. George's University",
#   'domains': ['sgu.edu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.bke.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Budapest University of Economic Sciences and Public Administration',
#   'domains': ['bke.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.andrassyuni.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Andrassy Gyula German Speaking University Budapest',
#   'domains': ['andrassyuni.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.jpte.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Janus Pannonius University',
#   'domains': ['jpte.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.hupe.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Hungarian University of Physical Education',
#   'domains': ['hupe.hu']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.holar.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'Holar University College',
#   'domains': ['holar.is']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.elte.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Eötvös Lorand University',
#   'domains': ['elte.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.hiete.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Haynal Imre University of Health Sciences Budapest',
#   'domains': ['hiete.hu']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.ru.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'Reykjavík University',
#   'domains': ['ru.is']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.iti.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'Technological University of Iceland',
#   'domains': ['iti.is']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.hvanneyri.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'Hvanneyri Agricultural University',
#   'domains': ['hvanneyri.is']},
#  {'alpha_two_code': 'IS',
#   'web_pages': ['http://www.khi.is/'],
#   'country': 'Iceland',
#   'state-province': None,
#   'name': 'Iceland University of Education',
#   'domains': ['khi.is']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.sote.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Semmelweis University of Medical Sciences',
#   'domains': ['sote.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.tkbf.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Budapest Buddhist University',
#   'domains': ['tkbf.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.szie.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Szent István University',
#   'domains': ['szie.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.sze.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Séchenyi István University',
#   'domains': ['sze.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.ceu.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Central European University',
#   'domains': ['ceu.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.bme.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Technical University of Budapest',
#   'domains': ['bme.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.kgre.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Károl Gáspár University of the Reformed Church',
#   'domains': ['kgre.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.lib.klte.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Kossuth Lajos University',
#   'domains': ['lib.klte.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.kodolanyi.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Kodolanyi Janos University College',
#   'domains': ['kodolanyi.hu']},
#  {'alpha_two_code': 'HU',
#   'web_pages': ['http://www.ppke.hu/'],
#   'country': 'Hungary',
#   'state-province': None,
#   'name': 'Pázmány Péter Catholic University',
#   'domains': ['ppke.hu']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.auth.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Aristotle University of Thessaloniki',
#   'domains': ['auth.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.eap.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Hellenic Open University',
#   'domains': ['eap.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.duth.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Dimocritus University of Thrace',
#   'domains': ['duth.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.cityu.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'City University Athens',
#   'domains': ['cityu.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.panteion.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Panteios University of Economics and Political Sciences Athens',
#   'domains': ['panteion.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.ntua.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'National Technical University of Athens',
#   'domains': ['ntua.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.aueb.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Athens University of Economics and Business',
#   'domains': ['aueb.gr']},
#  {'alpha_two_code': 'GR',
#   'web_pages': ['http://www.aua.gr/'],
#   'country': 'Greece',
#   'state-province': None,
#   'name': 'Agricultural University of Athens',
#   'domains': ['aua.gr']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.ghanacu.org/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'Ghana Christian University College',
#   'domains': ['ghanacu.org']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.iug.edu.gh/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'Islamic University College',
#   'domains': ['iug.edu.gh']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.gtuc.edu.gh/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'Ghana Telecom University College',
#   'domains': ['gtuc.edu.gh']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.presbyuniversity.edu.gh/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'Presbyterian University College',
#   'domains': ['presbyuniversity.edu.gh']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.knust.edu.gh/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'Kwame Nkrumah University of Science and Technology',
#   'domains': ['knust.edu.gh']},
#  {'alpha_two_code': 'GH',
#   'web_pages': ['http://www.regentghana.net/'],
#   'country': 'Ghana',
#   'state-province': None,
#   'name': 'Regent University College of Science and Technology',
#   'domains': ['regentghana.net']},
#  ...]

# %%
len(dat)
# Out:
# 5004

# %%
dat[0].keys()
# Out:
# dict_keys(['alpha_two_code', 'web_pages', 'country', 'state-province', 'name', 'domains'])

# %%
import pandas as pd
dataf= pd.DataFrame(data=dat,columns=['alpha_two_code', 'web_pages', 'country', 'state-province', 'name', 'domains'])

# %%
dataf['domains']
# Out:
# 0             [ipfw.edu]
# 1            [iupui.edu]
# 2            [iupuc.edu]
# 3       [wsb-nlu.edu.pl]
# 4               [ukf.sk]
#               ...
# 4999       [howon.ac.kr]
# 5000        [gti.spb.ru]
# 5001          [mirea.ru]
# 5002        [mpei.ac.ru]
# 5003       [utar.edu.my]
# Name: domains, Length: 5004, dtype: object

# %%
def inser():   
    conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-LAFG171K;'
                      'Database=UNIV;'
                      'Trusted_Connection=yes;')
    
    cursor = conn.cursor()
    #ref=(alpha_two_code,web_pages,country,name,domains)
    for index,row in dataf.iterrows():
        a=dataf['alpha_two_code'][index]
        w=dataf['web_pages'][index]
        c=dataf['country'][index]
        s=dataf['state-province'][index]
        n=dataf['name'][index]
        d=dataf['domains'][index]
        cursor.execute("INSERT INTO dbo.tab4 VALUES (?,?,?,?,?,?)",str(a),str(w),str(c),str(s),str(n),str(d))
    
    cursor.commit()
    cursor.close()

# %%
inser()
